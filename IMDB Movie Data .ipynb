# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t',low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t',low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t',low_memory=False)

# %% [markdown]
# Filter/Cleaning Title Basics:

# %%
basics.replace({'\\N':np.nan},inplace=True)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9294674 entries, 0 to 9294673
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 638.2+ MB

# %%
basics = basics.dropna(subset=['runtimeMinutes','genres'])

# %%
basics['titleType']=='movie'
# Out:
# 0          False
# 1          False
# 2          False
# 3          False
# 4          False
#            ...
# 9294624     True
# 9294630    False
# 9294665    False
# 9294672    False
# 9294673    False
# Name: titleType, Length: 2435459, dtype: bool

# %%
basics = basics.loc[basics['titleType']=='movie']
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# 1172     tt0001184     movie
# ...            ...       ...
# 9294439  tt9916362     movie
# 9294523  tt9916538     movie
# 9294564  tt9916622     movie
# 9294591  tt9916680     movie
# 9294624  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# 1172                               Don Juan de Serrallonga
# ...                                                    ...
# 9294439                                              Coven
# 9294523                                Kuambil Lagi Hatiku
# 9294564        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9294591  De la ilusión al desconcierto: cine colombiano...
# 9294624                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# 1172                               Don Juan de Serrallonga       0      1910
# ...                                                    ...     ...       ...
# 9294439                                           Akelarre       0      2020
# 9294523                                Kuambil Lagi Hatiku       0      2019
# 9294564        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9294591  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9294624                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# 1172        NaN             58             Adventure,Drama
# ...         ...            ...                         ...
# 9294439     NaN             92               Drama,History
# 9294523     NaN            123                       Drama
# 9294564     NaN             57                 Documentary
# 9294591     NaN            100                 Documentary
# 9294624     NaN             49                 Documentary
#
# [369604 rows x 9 columns]

# %%
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
basics['startYear'].str.strip()
# Out:
# 8          1894
# 570        1906
# 587        1907
# 672        1908
# 1172       1910
#            ...
# 9294346    2019
# 9294355    2020
# 9294394    2020
# 9294439    2020
# 9294523    2019
# Name: startYear, Length: 281379, dtype: object

# %%
basics= basics.dropna(subset=['startYear'])

# %%
basics['startYear'] = basics['startYear'].astype(float)

# %%
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult            object
# startYear         float64
# endYear            object
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 1172     tt0001184     movie         Don Juan de Serrallonga
# ...            ...       ...                             ...
# 9294346  tt9916170     movie                   The Rehearsal
# 9294355  tt9916190     movie                       Safeguard
# 9294394  tt9916270     movie        Il talento del calabrone
# 9294439  tt9916362     movie                           Coven
# 9294523  tt9916538     movie             Kuambil Lagi Hatiku
#
#                           originalTitle isAdult  startYear endYear  \
# 8                            Miss Jerry       0     1894.0     NaN
# 570         The Story of the Kelly Gang       0     1906.0     NaN
# 587                   L'enfant prodigue       0     1907.0     NaN
# 672      The Fairylogue and Radio-Plays       0     1908.0     NaN
# 1172            Don Juan de Serrallonga       0     1910.0     NaN
# ...                                 ...     ...        ...     ...
# 9294346                        O Ensaio       0     2019.0     NaN
# 9294355                       Safeguard       0     2020.0     NaN
# 9294394        Il talento del calabrone       0     2020.0     NaN
# 9294439                        Akelarre       0     2020.0     NaN
# 9294523             Kuambil Lagi Hatiku       0     2019.0     NaN
#
#         runtimeMinutes                      genres
# 8                   45                     Romance
# 570                 70  Action,Adventure,Biography
# 587                 90                       Drama
# 672                120           Adventure,Fantasy
# 1172                58             Adventure,Drama
# ...                ...                         ...
# 9294346             51                       Drama
# 9294355             95   Action,Adventure,Thriller
# 9294394             84                    Thriller
# 9294439             92               Drama,History
# 9294523            123                       Drama
#
# [277017 rows x 9 columns]

# %%
basics=basics[(basics['startYear']>=2000)& (basics['startYear']<2022)]

# %%
basics['startYear'].value_counts()
# Out:
# 2018.0    9593
# 2017.0    9413
# 2019.0    9312
# 2016.0    8998
# 2015.0    8554
# 2014.0    8148
# 2021.0    8032
# 2013.0    7772
# 2020.0    7491
# 2012.0    7275
# 2011.0    6743
# 2010.0    6349
# 2009.0    5962
# 2008.0    5194
# 2007.0    4606
# 2006.0    4371
# 2005.0    3891
# 2004.0    3511
# 2003.0    3215
# 2002.0    2974
# 2001.0    2848
# 2000.0    2717
# Name: startYear, dtype: int64

# %%
keepers = basics['tconst'].isin(akas['titleId'])

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 67640    tt0069049     movie
# 77934    tt0079644     movie
# 86770    tt0088751     movie
# ...            ...       ...
# 9294346  tt9916170     movie
# 9294355  tt9916190     movie
# 9294394  tt9916270     movie
# 9294439  tt9916362     movie
# 9294523  tt9916538     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 67640                           The Other Side of the Wind
# 77934                                        November 1828
# 86770                                    The Naked Monster
# ...                                                    ...
# 9294346                                      The Rehearsal
# 9294355                                          Safeguard
# 9294394                           Il talento del calabrone
# 9294439                                              Coven
# 9294523                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear endYear  \
# 34792                               Kate & Leopold       0     2001.0     NaN
# 61094    El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67640                   The Other Side of the Wind       0     2018.0     NaN
# 77934                                November 1828       0     2001.0     NaN
# 86770                            The Naked Monster       0     2005.0     NaN
# ...                                            ...     ...        ...     ...
# 9294346                                   O Ensaio       0     2019.0     NaN
# 9294355                                  Safeguard       0     2020.0     NaN
# 9294394                   Il talento del calabrone       0     2020.0     NaN
# 9294439                                   Akelarre       0     2020.0     NaN
# 9294523                        Kuambil Lagi Hatiku       0     2019.0     NaN
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 61094               70                      Drama
# 67640              122                      Drama
# 77934              140                  Drama,War
# 86770              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9294346             51                      Drama
# 9294355             95  Action,Adventure,Thriller
# 9294394             84                   Thriller
# 9294439             92              Drama,History
# 9294523            123                      Drama
#
# [136337 rows x 9 columns]

# %%
akas.replace({'\\N':np.nan},inplace=True)

# %%
akas.head()
# Out:
#      titleId  ordering                      title region language  types  \
# 0  tt0000001         1                 Карменсіта     UA      NaN    NaN
# 1  tt0000001         2                 Carmencita     DE      NaN    NaN
# 2  tt0000001         3  Carmencita - spanyol tánc     HU      NaN    NaN
# 3  tt0000001         4                 Καρμενσίτα     GR      NaN    NaN
# 4  tt0000001         5                 Карменсита     RU      NaN    NaN
#
#    attributes isOriginalTitle
# 0         NaN               0
# 1         NaN               0
# 2         NaN               0
# 3         NaN               0
# 4         NaN               0

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33484260 entries, 0 to 33484259
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            float64
#  6   attributes       float64
#  7   isOriginalTitle  object
# dtypes: float64(2), int64(1), object(5)
# memory usage: 2.0+ GB

# %%
akas['region']=='US'
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 33484255    False
# 33484256    False
# 33484257    False
# 33484258    False
# 33484259    False
# Name: region, Length: 33484260, dtype: bool

# %%
akas = akas.loc[akas['region']=='US']
akas
# Out:
#             titleId  ordering                          title region language  \
# 5         tt0000001         6                     Carmencita     US      NaN
# 14        tt0000002         7         The Clown and His Dogs     US      NaN
# 33        tt0000005        10               Blacksmith Scene     US      NaN
# 36        tt0000005         1            Blacksmithing Scene     US      NaN
# 41        tt0000005         6            Blacksmith Scene #1     US      NaN
# ...             ...       ...                            ...    ...      ...
# 33483932  tt9916702         1  Loving London: The Playground     US      NaN
# 33483969  tt9916720        10                The Demonic Nun     US      NaN
# 33483971  tt9916720        12                      The Nun 2     US      NaN
# 33483988  tt9916756         1       Pretty Pretty Black Girl     US      NaN
# 33484004  tt9916764         1                             38     US      NaN
#
#           types  attributes isOriginalTitle
# 5           NaN         NaN               0
# 14          NaN         NaN               0
# 33          NaN         NaN               0
# 36          NaN         NaN               0
# 41          NaN         NaN               0
# ...         ...         ...             ...
# 33483932    NaN         NaN               0
# 33483969    NaN         NaN               0
# 33483971    NaN         NaN               0
# 33483988    NaN         NaN               0
# 33484004    NaN         NaN               0
#
# [1359815 rows x 8 columns]

# %%
ratings.replace({'\\N':np.nan},inplace=True)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1920
# 1  tt0000002            5.8       260
# 2  tt0000003            6.5      1726
# 3  tt0000004            5.6       173
# 4  tt0000005            6.2      2542

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1237493 entries, 0 to 1237492
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1237493 non-null  object
#  1   averageRating  1237493 non-null  float64
#  2   numVotes       1237493 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.3+ MB

# %%
keeper = ratings['tconst'].isin(akas['titleId'])
keeper
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1237488    False
# 1237489     True
# 1237490    False
# 1237491    False
# 1237492    False
# Name: tconst, Length: 1237493, dtype: bool

# %%
ratings = ratings[keeper]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1920
# 1        tt0000002            5.8       260
# 4        tt0000005            6.2      2542
# 5        tt0000006            5.1       175
# 6        tt0000007            5.4       796
# ...            ...            ...       ...
# 1237467  tt9916204            8.2       245
# 1237473  tt9916348            8.5        17
# 1237474  tt9916362            6.4      4914
# 1237478  tt9916428            3.8        14
# 1237489  tt9916720            5.3       266
#
# [471775 rows x 3 columns]

# %%
import os
os.makedirs('Data/',exist_ok=True)
os.listdir('Data/')
# Out:
# []

# %%
basics.to_csv('Data/title_basics.csv.gz',compression='gzip',index=False)

# %%
basics =pd.read_csv('Data/title_basics.csv.gz',low_memory=False)
basics.head()
# Out:
#       tconst titleType                                       primaryTitle  \
# 0  tt0035423     movie                                     Kate & Leopold
# 1  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 2  tt0069049     movie                         The Other Side of the Wind
# 3  tt0079644     movie                                      November 1828
# 4  tt0088751     movie                                  The Naked Monster
#
#                                originalTitle  isAdult  startYear  endYear  \
# 0                             Kate & Leopold        0     2001.0      NaN
# 1  El Tango del Viudo y Su Espejo Deformante        0     2020.0      NaN
# 2                 The Other Side of the Wind        0     2018.0      NaN
# 3                              November 1828        0     2001.0      NaN
# 4                          The Naked Monster        0     2005.0      NaN
#
#    runtimeMinutes                  genres
# 0             118  Comedy,Fantasy,Romance
# 1              70                   Drama
# 2             122                   Drama
# 3             140               Drama,War
# 4             100    Comedy,Horror,Sci-Fi

# %%
akas.to_csv('Data/title_akas.csv.gz',compression='gzip',index=False)

# %%
akas = pd.read_csv('Data/title_akas.csv.gz',low_memory=False)
akas.head()
# Out:
#      titleId  ordering                   title region language  types  \
# 0  tt0000001         6              Carmencita     US      NaN    NaN
# 1  tt0000002         7  The Clown and His Dogs     US      NaN    NaN
# 2  tt0000005        10        Blacksmith Scene     US      NaN    NaN
# 3  tt0000005         1     Blacksmithing Scene     US      NaN    NaN
# 4  tt0000005         6     Blacksmith Scene #1     US      NaN    NaN
#
#    attributes  isOriginalTitle
# 0         NaN              0.0
# 1         NaN              0.0
# 2         NaN              0.0
# 3         NaN              0.0
# 4         NaN              0.0

# %%
ratings.to_csv('Data/title_ratings.csv.gz',compression='gzip',index=False)

# %%
ratings = pd.read_csv('Data/title_ratings.csv.gz',low_memory=False)
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1920
# 1  tt0000002            5.8       260
# 2  tt0000005            6.2      2542
# 3  tt0000006            5.1       175
# 4  tt0000007            5.4       796
