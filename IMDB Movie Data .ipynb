# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
basics_url = "https://datasets.imdbws.com/title.basics.tsv.gz"

# %%
akas_url = "https://datasets.imdbws.com/title.akas.tsv.gz"

# %%
ratings_url = "https://datasets.imdbws.com/title.ratings.tsv.gz"

# %%
basics = pd.read_csv(basics_url, sep='\t',low_memory=False)

# %%
akas = pd.read_csv(akas_url, sep='\t',low_memory=False)

# %%
ratings = pd.read_csv(ratings_url, sep='\t',low_memory=False)

# %% [markdown]
# Filter/Cleaning Title Basics:

# %%
basics.replace({'\\N':np.nan},inplace=True)

# %%
basics.head()
# Out:
#       tconst titleType            primaryTitle           originalTitle  \
# 0  tt0000001     short              Carmencita              Carmencita
# 1  tt0000002     short  Le clown et ses chiens  Le clown et ses chiens
# 2  tt0000003     short          Pauvre Pierrot          Pauvre Pierrot
# 3  tt0000004     short             Un bon bock             Un bon bock
# 4  tt0000005     short        Blacksmith Scene        Blacksmith Scene
#
#   isAdult startYear endYear runtimeMinutes                    genres
# 0       0      1894     NaN              1         Documentary,Short
# 1       0      1892     NaN              5           Animation,Short
# 2       0      1892     NaN              4  Animation,Comedy,Romance
# 3       0      1892     NaN             12           Animation,Short
# 4       0      1893     NaN              1              Comedy,Short

# %%
basics.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9292084 entries, 0 to 9292083
# Data columns (total 9 columns):
#  #   Column          Dtype
# ---  ------          -----
#  0   tconst          object
#  1   titleType       object
#  2   primaryTitle    object
#  3   originalTitle   object
#  4   isAdult         object
#  5   startYear       object
#  6   endYear         object
#  7   runtimeMinutes  object
#  8   genres          object
# dtypes: object(9)
# memory usage: 638.0+ MB

# %%
basics = basics.dropna(subset=['runtimeMinutes','genres'])

# %%
basics['titleType']=='movie'
# Out:
# 8          True
# 570        True
# 587        True
# 672        True
# 1172       True
#            ...
# 9291849    True
# 9291933    True
# 9291974    True
# 9292001    True
# 9292034    True
# Name: titleType, Length: 369539, dtype: bool

# %%
basics = basics.loc[basics['titleType']=='movie']
basics
# Out:
#             tconst titleType  \
# 8        tt0000009     movie
# 570      tt0000574     movie
# 587      tt0000591     movie
# 672      tt0000679     movie
# 1172     tt0001184     movie
# ...            ...       ...
# 9291849  tt9916362     movie
# 9291933  tt9916538     movie
# 9291974  tt9916622     movie
# 9292001  tt9916680     movie
# 9292034  tt9916754     movie
#
#                                               primaryTitle  \
# 8                                               Miss Jerry
# 570                            The Story of the Kelly Gang
# 587                                       The Prodigal Son
# 672                         The Fairylogue and Radio-Plays
# 1172                               Don Juan de Serrallonga
# ...                                                    ...
# 9291849                                              Coven
# 9291933                                Kuambil Lagi Hatiku
# 9291974        Rodolpho Teóphilo - O Legado de um Pioneiro
# 9292001  De la ilusión al desconcierto: cine colombiano...
# 9292034                     Chico Albuquerque - Revelações
#
#                                              originalTitle isAdult startYear  \
# 8                                               Miss Jerry       0      1894
# 570                            The Story of the Kelly Gang       0      1906
# 587                                      L'enfant prodigue       0      1907
# 672                         The Fairylogue and Radio-Plays       0      1908
# 1172                               Don Juan de Serrallonga       0      1910
# ...                                                    ...     ...       ...
# 9291849                                           Akelarre       0      2020
# 9291933                                Kuambil Lagi Hatiku       0      2019
# 9291974        Rodolpho Teóphilo - O Legado de um Pioneiro       0      2015
# 9292001  De la ilusión al desconcierto: cine colombiano...       0      2007
# 9292034                     Chico Albuquerque - Revelações       0      2013
#
#         endYear runtimeMinutes                      genres
# 8           NaN             45                     Romance
# 570         NaN             70  Action,Adventure,Biography
# 587         NaN             90                       Drama
# 672         NaN            120           Adventure,Fantasy
# 1172        NaN             58             Adventure,Drama
# ...         ...            ...                         ...
# 9291849     NaN             92               Drama,History
# 9291933     NaN            123                       Drama
# 9291974     NaN             57                 Documentary
# 9292001     NaN            100                 Documentary
# 9292034     NaN             49                 Documentary
#
# [369539 rows x 9 columns]

# %%
is_documentary = basics['genres'].str.contains('documentary',case=False)
basics = basics[~is_documentary]

# %%
basics['startYear'].str.strip()
# Out:
# 8          1894
# 570        1906
# 587        1907
# 672        1908
# 1172       1910
#            ...
# 9291756    2019
# 9291765    2020
# 9291804    2020
# 9291849    2020
# 9291933    2019
# Name: startYear, Length: 281337, dtype: object

# %%
basics= basics.dropna(subset=['startYear'])

# %%
basics['startYear'] = basics['startYear'].astype(float)

# %%
basics.dtypes
# Out:
# tconst             object
# titleType          object
# primaryTitle       object
# originalTitle      object
# isAdult            object
# startYear         float64
# endYear            object
# runtimeMinutes     object
# genres             object
# dtype: object

# %%
basics
# Out:
#             tconst titleType                    primaryTitle  \
# 8        tt0000009     movie                      Miss Jerry
# 570      tt0000574     movie     The Story of the Kelly Gang
# 587      tt0000591     movie                The Prodigal Son
# 672      tt0000679     movie  The Fairylogue and Radio-Plays
# 1172     tt0001184     movie         Don Juan de Serrallonga
# ...            ...       ...                             ...
# 9291756  tt9916170     movie                   The Rehearsal
# 9291765  tt9916190     movie                       Safeguard
# 9291804  tt9916270     movie        Il talento del calabrone
# 9291849  tt9916362     movie                           Coven
# 9291933  tt9916538     movie             Kuambil Lagi Hatiku
#
#                           originalTitle isAdult  startYear endYear  \
# 8                            Miss Jerry       0     1894.0     NaN
# 570         The Story of the Kelly Gang       0     1906.0     NaN
# 587                   L'enfant prodigue       0     1907.0     NaN
# 672      The Fairylogue and Radio-Plays       0     1908.0     NaN
# 1172            Don Juan de Serrallonga       0     1910.0     NaN
# ...                                 ...     ...        ...     ...
# 9291756                        O Ensaio       0     2019.0     NaN
# 9291765                       Safeguard       0     2020.0     NaN
# 9291804        Il talento del calabrone       0     2020.0     NaN
# 9291849                        Akelarre       0     2020.0     NaN
# 9291933             Kuambil Lagi Hatiku       0     2019.0     NaN
#
#         runtimeMinutes                      genres
# 8                   45                     Romance
# 570                 70  Action,Adventure,Biography
# 587                 90                       Drama
# 672                120           Adventure,Fantasy
# 1172                58             Adventure,Drama
# ...                ...                         ...
# 9291756             51                       Drama
# 9291765             95   Action,Adventure,Thriller
# 9291804             84                    Thriller
# 9291849             92               Drama,History
# 9291933            123                       Drama
#
# [276977 rows x 9 columns]

# %%
basics=basics[(basics['startYear']>=2000)& (basics['startYear']<2022)]

# %%
basics['startYear'].value_counts()
# Out:
# 2018.0    9590
# 2017.0    9413
# 2019.0    9316
# 2016.0    8998
# 2015.0    8554
# 2014.0    8148
# 2021.0    8029
# 2013.0    7772
# 2020.0    7489
# 2012.0    7275
# 2011.0    6744
# 2010.0    6349
# 2009.0    5962
# 2008.0    5194
# 2007.0    4606
# 2006.0    4371
# 2005.0    3891
# 2004.0    3511
# 2003.0    3215
# 2002.0    2974
# 2001.0    2848
# 2000.0    2717
# Name: startYear, dtype: int64

# %%
keepers = basics['tconst'].isin(akas['titleId'])

# %%
basics = basics[keepers]
basics
# Out:
#             tconst titleType  \
# 34792    tt0035423     movie
# 61094    tt0062336     movie
# 67640    tt0069049     movie
# 77934    tt0079644     movie
# 86770    tt0088751     movie
# ...            ...       ...
# 9291756  tt9916170     movie
# 9291765  tt9916190     movie
# 9291804  tt9916270     movie
# 9291849  tt9916362     movie
# 9291933  tt9916538     movie
#
#                                               primaryTitle  \
# 34792                                       Kate & Leopold
# 61094    The Tango of the Widower and Its Distorting Mi...
# 67640                           The Other Side of the Wind
# 77934                                        November 1828
# 86770                                    The Naked Monster
# ...                                                    ...
# 9291756                                      The Rehearsal
# 9291765                                          Safeguard
# 9291804                           Il talento del calabrone
# 9291849                                              Coven
# 9291933                                Kuambil Lagi Hatiku
#
#                                      originalTitle isAdult  startYear endYear  \
# 34792                               Kate & Leopold       0     2001.0     NaN
# 61094    El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67640                   The Other Side of the Wind       0     2018.0     NaN
# 77934                                November 1828       0     2001.0     NaN
# 86770                            The Naked Monster       0     2005.0     NaN
# ...                                            ...     ...        ...     ...
# 9291756                                   O Ensaio       0     2019.0     NaN
# 9291765                                  Safeguard       0     2020.0     NaN
# 9291804                   Il talento del calabrone       0     2020.0     NaN
# 9291849                                   Akelarre       0     2020.0     NaN
# 9291933                        Kuambil Lagi Hatiku       0     2019.0     NaN
#
#         runtimeMinutes                     genres
# 34792              118     Comedy,Fantasy,Romance
# 61094               70                      Drama
# 67640              122                      Drama
# 77934              140                  Drama,War
# 86770              100       Comedy,Horror,Sci-Fi
# ...                ...                        ...
# 9291756             51                      Drama
# 9291765             95  Action,Adventure,Thriller
# 9291804             84                   Thriller
# 9291849             92              Drama,History
# 9291933            123                      Drama
#
# [136334 rows x 9 columns]

# %%
akas.replace({'\\N':np.nan},inplace=True)

# %%
akas.head()
# Out:
#           tconst titleType                                       primaryTitle  \
# 34792  tt0035423     movie                                     Kate & Leopold
# 61094  tt0062336     movie  The Tango of the Widower and Its Distorting Mi...
# 67640  tt0069049     movie                         The Other Side of the Wind
# 77934  tt0079644     movie                                      November 1828
# 86770  tt0088751     movie                                  The Naked Monster
#
#                                    originalTitle isAdult  startYear endYear  \
# 34792                             Kate & Leopold       0     2001.0     NaN
# 61094  El Tango del Viudo y Su Espejo Deformante       0     2020.0     NaN
# 67640                 The Other Side of the Wind       0     2018.0     NaN
# 77934                              November 1828       0     2001.0     NaN
# 86770                          The Naked Monster       0     2005.0     NaN
#
#       runtimeMinutes                  genres
# 34792            118  Comedy,Fantasy,Romance
# 61094             70                   Drama
# 67640            122                   Drama
# 77934            140               Drama,War
# 86770            100    Comedy,Horror,Sci-Fi

# %%
akas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33465321 entries, 0 to 33465320
# Data columns (total 8 columns):
#  #   Column           Dtype
# ---  ------           -----
#  0   titleId          object
#  1   ordering         int64
#  2   title            object
#  3   region           object
#  4   language         object
#  5   types            object
#  6   attributes       object
#  7   isOriginalTitle  object
# dtypes: int64(1), object(7)
# memory usage: 2.0+ GB

# %%
akas['region']=='US'
# Out:
# 0           False
# 1           False
# 2           False
# 3           False
# 4           False
#             ...
# 33465316    False
# 33465317    False
# 33465318    False
# 33465319    False
# 33465320    False
# Name: region, Length: 33465321, dtype: bool

# %%
akas = akas.loc[akas['region']=='US']
akas
# Out:
#             titleId  ordering                          title region language  \
# 5         tt0000001         6                     Carmencita     US      NaN
# 14        tt0000002         7         The Clown and His Dogs     US      NaN
# 33        tt0000005        10               Blacksmith Scene     US      NaN
# 36        tt0000005         1            Blacksmithing Scene     US      NaN
# 41        tt0000005         6            Blacksmith Scene #1     US      NaN
# ...             ...       ...                            ...    ...      ...
# 33464993  tt9916702         1  Loving London: The Playground     US      NaN
# 33465030  tt9916720        10                The Demonic Nun     US      NaN
# 33465032  tt9916720        12                      The Nun 2     US      NaN
# 33465049  tt9916756         1       Pretty Pretty Black Girl     US      NaN
# 33465065  tt9916764         1                             38     US      NaN
#
#                 types             attributes isOriginalTitle
# 5         imdbDisplay                    NaN               0
# 14                NaN  literal English title               0
# 33        imdbDisplay                    NaN               0
# 36        alternative                    NaN               0
# 41        alternative                    NaN               0
# ...               ...                    ...             ...
# 33464993          NaN                    NaN               0
# 33465030           tv                    NaN               0
# 33465032  imdbDisplay                    NaN               0
# 33465049  imdbDisplay                    NaN               0
# 33465065  imdbDisplay                    NaN               0
#
# [1359209 rows x 8 columns]

# %%
ratings.replace({'\\N':np.nan},inplace=True)

# %%
ratings.head()
# Out:
#       tconst  averageRating  numVotes
# 0  tt0000001            5.7      1917
# 1  tt0000002            5.8       260
# 2  tt0000003            6.5      1725
# 3  tt0000004            5.6       173
# 4  tt0000005            6.2      2541

# %%
ratings.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1238083 entries, 0 to 1238082
# Data columns (total 3 columns):
#  #   Column         Non-Null Count    Dtype
# ---  ------         --------------    -----
#  0   tconst         1238083 non-null  object
#  1   averageRating  1238083 non-null  float64
#  2   numVotes       1238083 non-null  int64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 28.3+ MB

# %%
keeper = ratings['tconst'].isin(akas['titleId'])
keeper
# Out:
# 0           True
# 1           True
# 2          False
# 3          False
# 4           True
#            ...
# 1238078    False
# 1238079     True
# 1238080    False
# 1238081    False
# 1238082    False
# Name: tconst, Length: 1238083, dtype: bool

# %%
ratings = ratings[keeper]
ratings
# Out:
#             tconst  averageRating  numVotes
# 0        tt0000001            5.7      1917
# 1        tt0000002            5.8       260
# 4        tt0000005            6.2      2541
# 5        tt0000006            5.1       175
# 6        tt0000007            5.4       796
# ...            ...            ...       ...
# 1238057  tt9916204            8.2       245
# 1238063  tt9916348            8.5        17
# 1238064  tt9916362            6.4      4914
# 1238068  tt9916428            3.8        14
# 1238079  tt9916720            5.3       265
#
# [471781 rows x 3 columns]
