# %%
import  numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import os, json

# %%
df_2000=pd.read_csv('final_tmdb_data_2000.csv.gz')
df_2000.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0062336    0.0  /fw5tsNib4QZBEw18xmebpVe3WZ8.jpg                   NaN
# 3  tt0069049    0.0  /zjG95oDnBcFKMPgBEmmuNVOMC90.jpg                   NaN
# 4  tt0079644    0.0  /79axmuH1UGkB7m72jjB9rPff9om.jpg                   NaN
#
#        budget                                             genres  \
# 0         NaN                                                NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...
# 2         0.0  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 3  12000000.0                      [{'id': 18, 'name': 'Drama'}]
# 4         0.0                     [{'id': 10752, 'name': 'War'}]
#
#                                     homepage        id original_language  \
# ...

# %%
df_2000.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2480 entries, 0 to 2479
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2480 non-null   object
#  1   adult                  2479 non-null   float64
#  2   backdrop_path          1122 non-null   object
#  3   belongs_to_collection  159 non-null    object
#  4   budget                 2479 non-null   float64
#  5   genres                 2479 non-null   object
#  6   homepage               124 non-null    object
#  7   id                     2479 non-null   float64
#  8   original_language      2479 non-null   object
#  9   original_title         2479 non-null   object
#  10  overview               2291 non-null   object
#  11  popularity             2479 non-null   float64
#  12  poster_path            2099 non-null   object
#  13  production_companies   2479 non-null   object
# ...

# %%
df_2000.duplicated().sum()
# Out:
# 0

# %%
df_2001 = pd.read_csv('final_tmdb_data_2001.csv.gz')
df_2001.head()
# Out:
#      imdb_id  adult                     backdrop_path belongs_to_collection  \
# 0          0    NaN                               NaN                   NaN
# 1  tt0035423    0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg                   NaN
# 2  tt0079644    0.0  /79axmuH1UGkB7m72jjB9rPff9om.jpg                   NaN
# 3  tt0089067    0.0                               NaN                   NaN
# 4  tt0114447    0.0                               NaN                   NaN
#
#        budget                                             genres homepage  \
# 0         NaN                                                NaN      NaN
# 1  48000000.0  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...      NaN
# 2         0.0                     [{'id': 10752, 'name': 'War'}]      NaN
# 3         0.0                     [{'id': 35, 'name': 'Comedy'}]      NaN
# 4         0.0  [{'id': 53, 'name': 'Thriller'}, {'id': 28, 'n...      NaN
#
# ...

# %%
df_2001.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2261 entries, 0 to 2260
# Data columns (total 26 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   imdb_id                2261 non-null   object
#  1   adult                  2260 non-null   float64
#  2   backdrop_path          974 non-null    object
#  3   belongs_to_collection  116 non-null    object
#  4   budget                 2260 non-null   float64
#  5   genres                 2260 non-null   object
#  6   homepage               141 non-null    object
#  7   id                     2260 non-null   float64
#  8   original_language      2260 non-null   object
#  9   original_title         2260 non-null   object
#  10  overview               2090 non-null   object
#  11  popularity             2260 non-null   float64
#  12  poster_path            1915 non-null   object
#  13  production_companies   2260 non-null   object
# ...

# %%
df_2001.duplicated().sum()
# Out:
# 0

# %%
merged = pd.merge(df_2000,df_2001, on ='id', how='inner')
merged.head(3)
# Out:
#    imdb_id_x  adult_x                   backdrop_path_x  \
# 0          0      NaN                               NaN
# 1  tt0035423      0.0  /ab5yL8zgRotrICzGbEl10z24N71.jpg
# 2  tt0079644      0.0  /79axmuH1UGkB7m72jjB9rPff9om.jpg
#
#   belongs_to_collection_x    budget_x  \
# 0                     NaN         NaN
# 1                     NaN  48000000.0
# 2                     NaN         0.0
#
#                                             genres_x homepage_x        id  \
# 0                                                NaN        NaN       NaN
# 1  [{'id': 35, 'name': 'Comedy'}, {'id': 14, 'nam...        NaN   11232.0
# 2                     [{'id': 10752, 'name': 'War'}]        NaN  285529.0
#
#   original_language_x original_title_x  ...   revenue_y  runtime_y  \
# 0                 NaN              NaN  ...         NaN        NaN
# 1                  en   Kate & Leopold  ...  76019048.0      118.0
# 2                  id    November 1828  ...         0.0      140.0
#
# ...

# %%
merged.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 150 entries, 0 to 149
# Data columns (total 51 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   imdb_id_x                150 non-null    object
#  1   adult_x                  149 non-null    float64
#  2   backdrop_path_x          85 non-null     object
#  3   belongs_to_collection_x  13 non-null     object
#  4   budget_x                 149 non-null    float64
#  5   genres_x                 149 non-null    object
#  6   homepage_x               12 non-null     object
#  7   id                       149 non-null    float64
#  8   original_language_x      149 non-null    object
#  9   original_title_x         149 non-null    object
#  10  overview_x               147 non-null    object
#  11  popularity_x             149 non-null    float64
#  12  poster_path_x            134 non-null    object
#  13  production_companies_x   149 non-null    object
# ...

# %%
eda_merged=merged.copy()

# %%
eda_merged.dropna(inplace=True)

# %%
eda_merged.isna().sum()
# Out:
# imdb_id                    0
# adult_x                    0
# backdrop_path_x            0
# belongs_to_collection_x    0
# budget_x                   0
# genres_x                   0
# homepage_x                 0
# id_x                       0
# original_language_x        0
# original_title_x           0
# overview_x                 0
# popularity_x               0
# poster_path_x              0
# production_companies_x     0
# production_countries_x     0
# release_date_x             0
# revenue_x                  0
# runtime_x                  0
# spoken_languages_x         0
# status_x                   0
# tagline_x                  0
# title_x                    0
# video_x                    0
# vote_average_x             0
# vote_count_x               0
# certificiation_x           0
# adult_y                    0
# backdrop_path_y            0
# belongs_to_collection_y    0
# budget_y                   0
# genres_y                   0
# homepage_y                 0
# ...

# %%
eda_merged['budget_y'].value_counts()
# Out:
# 93000000.0     1
# 60000000.0     1
# 115000000.0    1
# Name: budget_y, dtype: int64

# %%
eda_merged['revenue_x'].value_counts()
# Out:
# 871368364.0    1
# 487853320.0    1
# 579707738.0    1
# Name: revenue_x, dtype: int64

# %%
eda_merged['revenue_y'].value_counts()
# Out:
# 871368364.0    1
# 487853320.0    1
# 579707738.0    1
# Name: revenue_y, dtype: int64

# %% [markdown]
# Question 1. How many movies had at least some valid financial information?

# %%
eda_merged.groupby('budget_x')['revenue_y'].mean()
# Out:
# budget_x
# 60000000.0     487853320.0
# 93000000.0     871368364.0
# 115000000.0    579707738.0
# Name: revenue_y, dtype: float64

# %%
sns.barplot(data=eda_merged, x='budget_x',y='revenue_y')
# Out:
# <AxesSubplot:xlabel='budget_x', ylabel='revenue_y'>

# %%
eda_merged['certificiation_x']
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In [12], line 1
# ----> 1 merged.groupby('certification_y')['']
#
# File ~\anaconda3\envs\dojo-env\lib\site-packages\pandas\core\frame.py:7712, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, observed, dropna)
#    7707 axis = self._get_axis_number(axis)
#    7709 # https://github.com/python/mypy/issues/7642
#    7710 # error: Argument "squeeze" to "DataFrameGroupBy" has incompatible type
#    7711 # "Union[bool, NoDefault]"; expected "bool"
# -> 7712 return DataFrameGroupBy(
#    7713     obj=self,
#    7714     keys=by,
#    7715     axis=axis,
#    7716     level=level,
#    7717     as_index=as_index,
#    7718     sort=sort,
#    7719     group_keys=group_keys,
#    7720     squeeze=squeeze,  # type: ignore[arg-type]
#    7721     observed=observed,
#    7722     dropna=dropna,
# ...
